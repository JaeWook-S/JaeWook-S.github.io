# %%
pip install pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 8.5 MB/s  0:00:00 eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

img1 = Image.open("cell_DIC.png")
img2 = Image.open("f1_tenth.png")

# 기준 이미지 크기 가져오기
target_size = img1.size  # (width, height)

# k1_kick을 동일 크기로 리사이즈
img2_resized = img2.resize(target_size)

img2_resized.save("f1_tenth.png")
